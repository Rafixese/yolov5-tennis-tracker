# %% [markdown]
# # Try out the model
#
# ## Perform checks

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 2024-7-28 Python-3.12.3 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 9993MiB)
# Setup complete ✅ (20 CPUs, 31.3 GB RAM, 102.9/294.2 GB disk)

# %% [markdown]
# ## Run detection

# %%
# !python detect.py --weights yolov5n.pt --img 640 --conf 0.25 --source ../Videos/singles/iga-01.mp4
# Out:
# detect: weights=['yolov5n.pt'], source=../Videos/singles/iga-01.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-7-28 Python-3.12.3 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 9993MiB)
#
# ...
# 100%|██████████████████████████████████████| 3.87M/3.87M [00:00<00:00, 19.4MB/s]
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# video 1/1 (1/343) /home/rafal/Projects/tennis-tracker/Videos/singles/iga-01.mp4: 384x640 2 persons, 1 chair, 29.1ms
# video 1/1 (2/343) /home/rafal/Projects/tennis-tracker/Videos/singles/iga-01.mp4: 384x640 2 persons, 1 chair, 4.1ms
# ...

# %% [markdown]
# ## Train model

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data ./data/tennis-ball-detection.v6i.yolov5pytorch/data.yaml --weights yolov5n.pt --name yolov5n-tennis-tracker
# Out:
# train: weights=yolov5n.pt, cfg=, data=./data/tennis-ball-detection.v6i.yolov5pytorch/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5n-tennis-tracker, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2024-7-28 Python-3.12.3 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 9993MiB)
#
# ...

# %% [markdown]
# ## Evaluate model on real video

# %%
# !python detect.py --weights yolov5n_tennis_tracker.pt --img 1080 --conf 0.22 --source ../Videos/singles/iga-32.mp4
# Out:
# detect: weights=['yolov5n_tennis_tracker.pt'], source=../Videos/singles/iga-32.mp4, data=data/coco128.yaml, imgsz=[1080, 1080], conf_thres=0.22, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2024-7-28 Python-3.12.3 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 9993MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# WARNING ⚠️ --img-size [1080, 1080] must be multiple of max stride 32, updating to [1088, 1088]
# video 1/1 (1/752) /home/rafal/Projects/tennis-tracker/Videos/singles/iga-32.mp4: 640x1088 (no detections), 31.6ms
# ...
